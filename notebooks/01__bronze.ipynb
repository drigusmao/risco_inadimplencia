# %%
#carregar os docs do catalogo

# %%
#posso dar um display para mostrar como está a tabela porem alertar que é só para vizualização e não para manipulação pois é uma tabela não tratada, ela é feita para refinamento e utilizamos apartir da silver

# %%
#não é comum criar tabelas aqui pois eles não estão tratados

# %%
#criando uma tabela temporaria para talvez utilizar na camada silver

# %%
#criar temporaria ou não? pq talvez use dps

# %%
spark.read.format('delta')
.load('/mnt/dados/dados_bronze')
.createOrReplaceTempView('dados_bronze')

# %%
#mapear todos carregamentos e criar varias tabelas temporarias com dicionário

bronze_path = { 
               'nome da tabela': '/mnt/dados/dados_bronze',
               'temp_bronzer_nomedatabela' #colocar tipo esse padrão
}

for view_name, path in bronze_path.items():
  (spark.read.format('delta')
  .load(path)
  .createOrReplaceTempView(view_name))

# %%
#leia cada tabela
