# %%
#aqui entra a inteligencia de negocio

# %%
#ex: total de vendas por dia, ordem com status de delivered, estado = ny.. por ai vai

# %%
#ler a tabela dnv

# %%
#criar um alerta que envia por email ou uma notificacao, envia algo, para o responsavel ou que crie uma lista com os dados dos clientes
#ex: todos que tiverem inadimplentes
#

# %%
#salva o df em formato delta na camada gold as regras de negocio

# %%
#adc na estrutura da pipeline e agenda-la

# %%
#cluster precisa ta ligado na hora de rodar?

# %%
#alerta de erro caso a pipiline tenha dado erro por teamns ou por e-mail

# %%
#schedules & triggers
#scheduled escolhe o dia e os horarios
