# %%
#captura dados da camada anterior

# %%
#ver possibilidade de tratar nulos, o que fazer se for nulo, se vai considerar, ver que comandos se consideram os nulos ou não, nao lembro qual faz isso, ja perguntar p chat, filtrar quando tiver puxando a tabela as colunas que serão utilizadas diminui tempo de processamento e custo

# %%
#criar (talvez) uma pasta para as camadas se ficar coisa demais aqui tratando cada tabela, mas só se necessário.

# %%
#colocar apenas tabelas que vamos utilizar

# %%
#le as tabelas com variaveis.. preciso fazer aqui dnv?

# %%
#criar tabelas temporarias... preciso fazer aqui dnv?

# %%
#criar data frma colocando modo overwrite, format delta, option margescrema true, save e colocar a pasta silver para ele salvar

# %%
#criar tabela fisica de teste

# %%
#join necessários

# %%
#CTE Common Table Expression é um bloco temporário de consulta dentro de SQL

# %%
#case when p mapear statuts

# %%
#ver que calculos/casewhen que são legais p criacao de colunas que são legais criar aqui

# %%
#salvar dataframe em tabela = salvar em delta
df.write.format("delta").saveAsTable("minha_tabela") # é aqui que salva no catalogo
#colocar nome_prod para rodar em produção, ver que nomemclaturas colocar

# %%
#Criando Job - Pipeline - colocar só os que tão prontos para pradução 
#coloca todas bronze ligando em valida_bronze dps todos silver tipo um diagrama

#eu posso tipo apagar tudo q ele vai ir criando a estrutura sozinho
.
